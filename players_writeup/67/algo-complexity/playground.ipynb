# %%
# SPFA  flag{YOU_Kn0W_TH3_DE@tH_oF_SPfA}
import random

MAXN = 2000
MAXM = 8000
MAXW = 1e9

SFPA_MAP = []
m = 0
sum_w = 0

for i in range(2,MAXN-1):
    w = (MAXN-i)*2+1
    sum_w += w+1
    SFPA_MAP.append(str(1)+" "+str(i+1)+" "+str(w)+"\n")
    SFPA_MAP.append(str(i+1)+" "+str(i)+" "+str(1)+"\n")
    m += 2

assert m <= MAXM
assert sum_w <= MAXW

# random.shuffle(SFPA_MAP)

HEAD = str(MAXN)+" "+str(m)+" "+str(1)+" "+str(MAXN)+"\n"

o = open("SPFA.txt", "w")
o.write(HEAD)
for i in SFPA_MAP:
    o.write(i)
o.close()

# #include<bits/stdc++.h>
# using namespace std;
# int main(){
# 	freopen("spfa6.out","w",stdout);
# 	int n=99999,m=199996;
# 	printf("%d %d\n",n,m);
# 	for(int i=n;i>=2;--i)
# 		printf("1 %d %d\n%d %d 1\n",i,(n-i+1)*2+1,i,i-1);
# }

# Author: wflight
# Link: http://yoursite.com/2019/10/19/如何卡SPFA/
# Source: WFLIGHT'S BLOG
# Copyright is owned by the author. For commercial reprints, please contact the author for authorization. For non-commercial reprints, please indicate the source.

# %%
MAXN = 100
MAXM = 5000
MAXW = 1e9

DINIC_MAP = []
m = 0
sum_w = 0

# %%
# Dinic flag{YOU_Kn0W_TH3_DE@tH_oF_DiNiC} - by Copilot

# https://www.sciencedirect.com/science/article/pii/089396599190145L
# 10.1016/0893-9659(91)90145-L

# Modified -  flag{Y0u_COmPlETe1Y_uND3rSt4nd_tH3_d1Nic_Algor1THM}

MAXN = 100
MAXM = 5000
MAXW = 1e9

DINIC_MAP = []
m = 0
sum_w = 0

for i in range(MAXN-1):
    DINIC_MAP.append(str(i+1)+" "+str(MAXN)+" "+str(1)+"\n")
    sum_w += 1
    m += 1
for i in range(MAXN-2):
    for j in range(MAXN-2-i):
    # for j in range(1):
        w = (j+1)*MAXN+random.randint(1,MAXN)
        if j == 0:
            DINIC_MAP.append(str(i+1)+" "+str(i+1+j+1)+" "+str(w)+"\n")
        else:
            DINIC_MAP.append(str(i+1+j+1)+" "+str(i+1)+" "+str(w)+"\n")
        sum_w += 1
        m += 1

assert m <= MAXM
assert sum_w <= MAXW

HEAD = str(MAXN)+" "+str(m)+" "+str(1)+" "+str(MAXN)+"\n"

o = open("Dinic.txt", "w")
o.write(HEAD)
for i in DINIC_MAP:
    o.write(i)
o.close()

# #include<bits/stdc++.h>
# #define int ll
# using namespace std;
# typedef long long ll;
# signed main()
# {
# 	freopen("P4001.in" , "w" , stdout);
# 	ios::sync_with_stdio(0);
# 	cin.tie(0) , cout.tie(0);
# 	int n = 1000 , m = n;
# 	cout << n << " " << m << "\n";
# 	for(int i = 1 ; i < n ; i++)
# 		cout << n - i << " \n"[i == n - 1];
# 	for(int i = 2 ; i < n ; i++)
# 		for(int j = 1 ; j < n ; j++)
# 			cout << 1 << " \n"[j == n - 1];
# 	for(int i = 1 ; i < n ; i++)
# 		cout << i << " \n"[i == n - 1];
# 	cout << "\n";
# 	for(int i = 1 ; i < n ; i++)
# 	{
# 		cout << n - i << ' ';
# 		for(int j = 2 ; j < n ; j++)
# 			cout << 1 << ' ';
# 		cout << i << "\n";
# 	}
# 	cout << "\n";
# 	for(int i = 1 ; i < n ; i++)
# 		for(int j = 1 ; j < n ; j++)
# 			cout << 1 << " \n"[j == n - 1];
# 	return 0;
# }

# https://www.luogu.com/discuss/723695?page=2
