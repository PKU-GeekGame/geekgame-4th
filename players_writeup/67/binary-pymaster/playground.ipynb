# %%
# https://pyinstxtractor-web.netlify.app

# random.pyc
# flag{wElc0me_tO_THe_w0RlD_OF_pYtHON}

import marshal, random, base64
random.seed('flag2 = flag{wElc0me_tO_THe_w0RlD_OF_pYtHON}')
if random.randint(0, 65535) == 54830:
    exec(marshal.loads(base64.b64decode(b'...')))
# Out:
# Try again!

# %%
import base64, dis
import uncompyle6.main
obj = marshal.loads(base64.b64decode(b'...'))
dis.dis(obj)
uncompyle6.main.decompile(obj)
# Out:
#   1           0 LOAD_CONST               0 (b'...')
#               2 STORE_NAME               0 (code)
#
#   2           4 LOAD_NAME                1 (eval)
#               6 LOAD_CONST               1 ('exec')
#               8 CALL_FUNCTION            1
#
#   3          10 LOAD_NAME                2 (getattr)
#              12 LOAD_NAME                3 (__import__)
#              14 LOAD_CONST               2 ('zlib')
#              16 CALL_FUNCTION            1
#              18 LOAD_CONST               3 ('decompress')
#              20 CALL_FUNCTION            2
#
#   4          22 LOAD_NAME                2 (getattr)
#              24 LOAD_NAME                3 (__import__)
#              26 LOAD_CONST               4 ('base64')
#              28 CALL_FUNCTION            1
#              30 LOAD_CONST               5 ('b64decode')
#              32 CALL_FUNCTION            2
#              34 LOAD_NAME                0 (code)
#              36 CALL_FUNCTION            1
#
# ...

# %%
import random, base64
if random.randint(0, 65535) == 54830:
    code = b'...'
    eval("exec")(getattr(__import__("zlib"), "decompress")(getattr(__import__("base64"), "b64decode")(code)))

# %%
code = b'...'
dat = getattr(__import__("zlib"), "decompress")(getattr(__import__("base64"), "b64decode")(code))
print(dat.decode("utf-8"))
# Out:
# import random
# import base64
#
# # flag1 = "flag{you_Ar3_tHE_MaSTer_OF_PY7h0n}"
#
#
# class adJGrTXOYN:
#     def __init__(adJGrTXOYP, OOOO, OOO0):
#         adJGrTXOYP.OOOO = OOOO
#         adJGrTXOYP.OOO0 = OOO0
#         adJGrTXOYP.OO0O = None
#         adJGrTXOYP.O0OO = None
#         adJGrTXOYP.O0O0 = None
#
#
# class adJGrTXOYb:
#     def __init__(adJGrTXOYP):
#         adJGrTXOYP.IIII = None
#
#     def adJGrTXOYb(adJGrTXOYP, adJGrTXOYo):
#         while adJGrTXOYo.OO0O != None:
#             if adJGrTXOYo.OO0O.OO0O == None:
#                 if adJGrTXOYo == adJGrTXOYo.OO0O.O0OO:
#                     adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O)
#                 else:
#                     adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O)
#             elif (
#                 adJGrTXOYo == adJGrTXOYo.OO0O.O0OO
#                 and adJGrTXOYo.OO0O == adJGrTXOYo.OO0O.OO0O.O0OO
#             ):
#                 adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O.OO0O)
# ...

# %%
import random
import base64

# flag1 = "flag{you_Ar3_tHE_MaSTer_OF_PY7h0n}"
random.seed('flag2 = flag{wElc0me_tO_THe_w0RlD_OF_pYtHON}')
assert random.randint(0, 65535) == 54830

class adJGrTXOYN:
    def __init__(adJGrTXOYP, OOOO, OOO0):
        adJGrTXOYP.OOOO = OOOO
        adJGrTXOYP.OOO0 = OOO0
        adJGrTXOYP.OO0O = None
        adJGrTXOYP.O0OO = None
        adJGrTXOYP.O0O0 = None


class adJGrTXOYb:
    def __init__(adJGrTXOYP):
        adJGrTXOYP.IIII = None

    def adJGrTXOYb(adJGrTXOYP, adJGrTXOYo):
        while adJGrTXOYo.OO0O != None:
            if adJGrTXOYo.OO0O.OO0O == None:
                if adJGrTXOYo == adJGrTXOYo.OO0O.O0OO:
                    adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O)
                else:
                    adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O)
            elif (
                adJGrTXOYo == adJGrTXOYo.OO0O.O0OO
                and adJGrTXOYo.OO0O == adJGrTXOYo.OO0O.OO0O.O0OO
            ):
                adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O.OO0O)
                adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O)
            elif (
                adJGrTXOYo == adJGrTXOYo.OO0O.O0O0
                and adJGrTXOYo.OO0O == adJGrTXOYo.OO0O.OO0O.O0O0
            ):
                adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O.OO0O)
                adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O)
            elif (
                adJGrTXOYo == adJGrTXOYo.OO0O.O0O0
                and adJGrTXOYo.OO0O == adJGrTXOYo.OO0O.OO0O.O0OO
            ):
                adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O)
                adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O)
            else:
                adJGrTXOYP.adJGrTXOYn(adJGrTXOYo.OO0O)
                adJGrTXOYP.adJGrTXOYV(adJGrTXOYo.OO0O)

    def adJGrTXOYV(adJGrTXOYP, x):
        y = x.O0O0
        x.O0O0 = y.O0OO
        if y.O0OO != None:
            y.O0OO.OO0O = x
        y.OO0O = x.OO0O
        if x.OO0O == None:
            adJGrTXOYP.IIII = y
        elif x == x.OO0O.O0OO:
            x.OO0O.O0OO = y
        else:
            x.OO0O.O0O0 = y
        y.O0OO = x
        x.OO0O = y

    def adJGrTXOYn(adJGrTXOYP, x):
        y = x.O0OO
        x.O0OO = y.O0O0
        if y.O0O0 != None:
            y.O0O0.OO0O = x
        y.OO0O = x.OO0O
        if x.OO0O == None:
            adJGrTXOYP.IIII = y
        elif x == x.OO0O.O0O0:
            x.OO0O.O0O0 = y
        else:
            x.OO0O.O0OO = y
        y.O0O0 = x
        x.OO0O = y

    def adJGrTXOYx(adJGrTXOYP, OOOO, OOO0):
        adJGrTXOYo = adJGrTXOYN(OOOO, OOO0)
        adJGrTXOYu = adJGrTXOYP.IIII
        OO0O = None
        while adJGrTXOYu != None:
            OO0O = adJGrTXOYu
            if OOOO < adJGrTXOYu.OOOO:
                adJGrTXOYu = adJGrTXOYu.O0OO
            else:
                adJGrTXOYu = adJGrTXOYu.O0O0
        adJGrTXOYo.OO0O = OO0O
        if OO0O == None:
            adJGrTXOYP.IIII = adJGrTXOYo
        elif OOOO < OO0O.OOOO:
            OO0O.O0OO = adJGrTXOYo
        else:
            OO0O.O0O0 = adJGrTXOYo
        adJGrTXOYP.adJGrTXOYb(adJGrTXOYo)


def adJGrTXOYQ(adJGrTXOYo):
    s = b""
    if adJGrTXOYo != None:
        # s += bytes([adJGrTXOYo.OOO0])
        s += bytes([adJGrTXOYo.OOO0 ^ random.randint(0, 0xFF)])
        s += adJGrTXOYQ(adJGrTXOYo.O0OO)
        s += adJGrTXOYQ(adJGrTXOYo.O0O0)
    return s


def adJGrTXOYy(adJGrTXOYj):
    adJGrTXOYu = adJGrTXOYj.IIII
    OO0O = None
    while adJGrTXOYu != None:
        OO0O = adJGrTXOYu
        if random.randint(0, 1) == 0:
            adJGrTXOYu = adJGrTXOYu.O0OO
        else:
            adJGrTXOYu = adJGrTXOYu.O0O0
    adJGrTXOYj.adJGrTXOYb(OO0O)


def adJGrTXOYD():
    random.seed(0)
    adJGrTXOYj = adJGrTXOYb()

    # adJGrTXOYh = input("Please enter the flag: ")
    adJGrTXOYh = "flag{=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ}"

    if len(adJGrTXOYh) != 36:
        print("Try again!")
        return
    if adJGrTXOYh[:5] != "flag{" or adJGrTXOYh[-1] != "}":
        print("Try again!")
        return

    for adJGrTXOYL in adJGrTXOYh:
        adJGrTXOYj.adJGrTXOYx(random.random(), ord(adJGrTXOYL))

    for _ in range(0x100):
        adJGrTXOYy(adJGrTXOYj)

    adJGrTXOYi = adJGrTXOYQ(adJGrTXOYj.IIII)
    adJGrTXOYU = base64.b64decode("7EclRYPIOsDvLuYKDPLPZi0JbLYB9bQo8CZDlFvwBY07cs6I")
    if adJGrTXOYi == adJGrTXOYU:
        print("You got the flag3!")
    else:
        print(base64.b64encode(adJGrTXOYi))
        print("Try again!")


if __name__ == "__main__":
    adJGrTXOYD()
# Out:
# b'Dzt8Tz+UTBb+a69ZX5TbBMMa/x9JGeaJJ9Pb/Hkufp/Paiyi'
# Try again!

# %%
import random
import base64

# flag1 = "flag{you_Ar3_tHE_MaSTer_OF_PY7h0n}"
random.seed('flag2 = flag{wElc0me_tO_THe_w0RlD_OF_pYtHON}')
assert random.randint(0, 65535) == 54830


class STATE_HELPER:
    def __init__(self, INIT_STATE_A, INIT_STATE_B):
        self.INIT_STATE_A = INIT_STATE_A
        self.INIT_STATE_B = INIT_STATE_B
        self.HELPER = None
        self.NEW_STATE_A = None
        self.NEW_STATE_B = None


class ENCODER:
    def __init__(self):
        self.STATE = None

    def ENCODER(self, encoder_state):
        while encoder_state.HELPER != None:
            if encoder_state.HELPER.HELPER == None:
                if encoder_state == encoder_state.HELPER.NEW_STATE_A:
                    self.update_new_state_A(encoder_state.HELPER)
                else:
                    self.update_new_state_B(encoder_state.HELPER)
            elif (
                encoder_state == encoder_state.HELPER.NEW_STATE_A
                and encoder_state.HELPER == encoder_state.HELPER.HELPER.NEW_STATE_A
            ):
                self.update_new_state_A(encoder_state.HELPER.HELPER)
                self.update_new_state_A(encoder_state.HELPER)
            elif (
                encoder_state == encoder_state.HELPER.NEW_STATE_B
                and encoder_state.HELPER == encoder_state.HELPER.HELPER.NEW_STATE_B
            ):
                self.update_new_state_B(encoder_state.HELPER.HELPER)
                self.update_new_state_B(encoder_state.HELPER)
            elif (
                encoder_state == encoder_state.HELPER.NEW_STATE_B
                and encoder_state.HELPER == encoder_state.HELPER.HELPER.NEW_STATE_A
            ):
                self.update_new_state_B(encoder_state.HELPER)
                self.update_new_state_A(encoder_state.HELPER)
            else:
                self.update_new_state_A(encoder_state.HELPER)
                self.update_new_state_B(encoder_state.HELPER)

    def update_new_state_B(self, x):
        y = x.NEW_STATE_B
        x.NEW_STATE_B = y.NEW_STATE_A
        if y.NEW_STATE_A != None:
            y.NEW_STATE_A.HELPER = x
        y.HELPER = x.HELPER
        if x.HELPER == None:
            self.STATE = y
        elif x == x.HELPER.NEW_STATE_A:
            x.HELPER.NEW_STATE_A = y
        else:
            x.HELPER.NEW_STATE_B = y
        y.NEW_STATE_A = x
        x.HELPER = y

    def update_new_state_A(self, x):
        y = x.NEW_STATE_A
        x.NEW_STATE_A = y.NEW_STATE_B
        if y.NEW_STATE_B != None:
            y.NEW_STATE_B.HELPER = x
        y.HELPER = x.HELPER
        if x.HELPER == None:
            self.STATE = y
        elif x == x.HELPER.NEW_STATE_B:
            x.HELPER.NEW_STATE_B = y
        else:
            x.HELPER.NEW_STATE_A = y
        y.NEW_STATE_B = x
        x.HELPER = y

    def ADD_INFO(self, INIT_STATE_A, INIT_STATE_B):
        encoder_state = STATE_HELPER(INIT_STATE_A, INIT_STATE_B)
        enc_flag = self.STATE
        HELPER = None
        while enc_flag != None:
            HELPER = enc_flag
            if INIT_STATE_A < enc_flag.INIT_STATE_A:
                enc_flag = enc_flag.NEW_STATE_A
            else:
                enc_flag = enc_flag.NEW_STATE_B
        encoder_state.HELPER = HELPER
        if HELPER == None:
            self.STATE = encoder_state
        elif INIT_STATE_A < HELPER.INIT_STATE_A:
            HELPER.NEW_STATE_A = encoder_state
        else:
            HELPER.NEW_STATE_B = encoder_state
        self.ENCODER(encoder_state)


def get_result(encoder_state):
    s = b""
    if encoder_state != None:
        s += bytes([encoder_state.INIT_STATE_B ^ random.randint(0, 0xFF)])
        s += get_result(encoder_state.NEW_STATE_A)
        s += get_result(encoder_state.NEW_STATE_B)
    return s


def final_encoder(flag_encoder):
    enc_flag = flag_encoder.STATE
    HELPER = None
    while enc_flag != None:
        HELPER = enc_flag
        if random.randint(0, 1) == 0:
            enc_flag = enc_flag.NEW_STATE_A
        else:
            enc_flag = enc_flag.NEW_STATE_B
    flag_encoder.ENCODER(HELPER)


def run():
    flag_encoder = ENCODER()

    # usr_flag = input("Please enter the flag: ")
    usr_flag = "flag{@Python3.8@Python3.8@Python3.8}"

    if len(usr_flag) != 36:
        print("Try again!")
        return
    if usr_flag[:5] != "flag{" or usr_flag[-1] != "}":
        print("Try again!")
        return

    for i in usr_flag:
        flag_encoder.ADD_INFO(random.random(), ord(i))

    for _ in range(0x100):
        final_encoder(flag_encoder)

    result = get_result(flag_encoder.STATE)
    enc_flag = base64.b64decode("7EclRYPIOsDvLuYKDPLPZi0JbLYB9bQo8CZDlFvwBY07cs6I")
    if result == enc_flag:
        print("You got the flag3!")
    else:
        print(base64.b64encode(result))
        print("Try again!")


if __name__ == "__main__":
    run()
# Out:
# b'gFolH8nRW8DRA/Q9Pt6seS0fA8kB26gDkCkelFvZHJgMR+WK'
# Try again!

# %%
key1 = b'flag{=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ}'
key2 = base64.b64decode("7EclRYPIOsDvLuYKDPLPZi0JbLYB9bQo8CZDlFvwBY07cs6I")
ans1 = b'DBlOF=Z{WJQUT?H>gSYX}MV@NRPfaAEIKGCL'
ans2 = b'\xf7w%~\xb7\xac9\xc0\xe8=\xe5\x00\x1e\x98\xb4\x17-5t\xa2\x01\xf8\x917\xed+v\x94[\xf0w\xa8/@\xc8\xa9'

rand = b""
deco = b""
for i in range(36):
    rand += bytes([ans1[i]^ans2[i]])
    deco += bytes([rand[i]^key2[i]])

# deco = b'_rltrYY{PYR_FU3OgoAL}@s_S_efaA7l_uEm'

flag = b""
for i in key1.decode():
    flag += bytes([deco[ans1.decode().find(i)]])
print(flag)
# Out:
# b'flag{YOU_ArE_7ru3lY_m@SteR_oF_sPLAY}'
