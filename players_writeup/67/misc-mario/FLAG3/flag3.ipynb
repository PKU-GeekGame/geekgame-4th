# %%
payload = open("../Super Mario Bros. (W) [!].bin","rb")
f = open("./RAM_SAVE.dump","wb")

b = payload.read(0x16B)
f.write(b)

b = payload.read(0x16) # ReadController @ 0x016B
f.write(b)

# Save Controller Input by frame

asm = b"" # :Entry @ 0x0181
# LDA # $FF ; READ 0xFF
asm += (b"\xA9"+b"\xFF")
# STA zpg $C1
asm += (b"\x85"+b"\xC1")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA zpg $C2
asm += (b"\x85"+b"\xC2")
# LDA # $03
asm += (b"\xA9"+b"\x03")
# STA zpg $C3
asm += (b"\x85"+b"\xC3")
# LDY # $00
asm += (b"\xA0"+b"\x00") 
asm += b"" # :Loop @ 0x018f
# JSR $016B
asm += (b"\x20"+b"\x6B"+b"\x01")
# STA (ind), Y $C2
asm += (b"\x91"+b"\xC2")
asm += b"" # :Wait @ 0x0194
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL @ 0x194 -> Wait -0x05
asm += (b"\x10"+b"\xFB")
# INY
asm += (b"\xC8")
# # CPY zpg $C1
# asm += (b"\xC4"+b"\xC1")
# CPY # $FF
asm += (b"\xC0"+b"\xFF")
# BCC @ 0x019C -> Loop -0x0F
asm += (b"\x90"+b"\xF1")
asm += b"" # :Lock @ 0x019E
# JMP @0x019E -> Lock
asm += (b"\x4C"+b"\x9E"+b"\x01")

l = len(asm)
print(hex(0x16B+0x16+l))
if l > 0x1E0-0x190:
    print("Error!")

payload.read(l)
b = payload.read(0x67F-l)
f.write(asm)
f.write(b)

payload.close()
f.close()

# 0x0160 - 0x1E8(?)
# Out:
# 0x1a1

# %%
payload = open("../Super Mario Bros. (W) [!].bin","rb")
f = open("./RAM_HIJK.dump","wb")

b = payload.read(0x16B)
f.write(b)

b = payload.read(0x16) # ReadController @ 0x016B
f.write(b)

# SHOW "HIJK"

asm = b"" # :Entry @ 0x0181
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $21
asm += (b"\xA9"+b"\x21")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $CA
asm += (b"\xA9"+b"\xCA")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $11
asm += (b"\xA9"+b"\x11")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# LDA # $12
asm += (b"\xA9"+b"\x12")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# LDA # $13
asm += (b"\xA9"+b"\x13")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# LDA # $14
asm += (b"\xA9"+b"\x14")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# LDA # $20
asm += (b"\xA9"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# STA abs $2005
asm += (b"\x8D"+b"\x05"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL @ 0x194 -> Wait -0x05
asm += (b"\x10"+b"\xFB")
# LDA # $0E
asm += (b"\xA9"+b"\x0E")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $10
asm += (b"\xA9"+b"\x10")
# STA abs $2000
asm += (b"\x8D"+b"\x00"+b"\x20")
asm += b"" # :Lock @ 0x1C3
# JMP @0x01C3 -> Lock
asm += (b"\x4C"+b"\xC3"+b"\x01")

l = len(asm)
print(hex(0x16B+0x16+l))
if l > 0x1E0-0x190:
    print("Error!")

payload.read(l)
b = payload.read(0x67F-l)
f.write(asm)
f.write(b)

payload.close()
f.close()

# 0x0160 - 0x1E8(?)
# Out:
# 0x1c6

# %%
payload = open("../Super Mario Bros. (W) [!].bin","rb")
f = open("./RAM_FAULT.dump","wb")

b = payload.read(0x16B)
f.write(b)

b = payload.read(0x16) # ReadController @ 0x016B
f.write(b)

# DISPLAY INPUT * 0x8F

asm = b"" # :Entry @ 0x0181
# LDX # $06
asm += (b"\xA2"+b"\x06")
# LDY # $00
asm += (b"\xA0"+b"\x00")
asm += b"" # :Loop @ 0x0185
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $21
asm += (b"\xA9"+b"\x21")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# STX abs $2006
asm += (b"\x8E"+b"\x06"+b"\x20")
# JSR $016B ; ReadController
asm += (b"\x20"+b"\x6B"+b"\x01")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# INX
asm += (b"\xE8")
# INY
asm += (b"\xC8")
# CPY # $10
asm += (b"\xC0"+b"\x10")
# BCC @ 0x019C -> Skip +0x06
asm += (b"\x90"+b"\x06")
# TXA
asm += (b"\x8A")
# ADC # $0F
asm += (b"\x69"+b"\x0F")
# TAX
asm += (b"\xAA")
# LDY # $00
asm += (b"\xA0"+b"\x00")
asm += b"" # :Skip @ 0x1A4
# LDA # $20
asm += (b"\xA9"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# STA abs $2005
asm += (b"\x8D"+b"\x05"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL @ 0x194 -> Wait -0x05
asm += (b"\x10"+b"\xFB")
# LDA # $0E
asm += (b"\xA9"+b"\x0E")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $10
asm += (b"\xA9"+b"\x10")
# STA abs $2000
asm += (b"\x8D"+b"\x00"+b"\x20")
# JMP @0x01C3 -> 0x0185
asm += (b"\x4C"+b"\x85"+b"\x01")


l = len(asm)
print(hex(0x16B+0x16+l))
if l > 0x1E0-0x190:
    print("Error!")

payload.read(l)
b = payload.read(0x67F-l)
f.write(asm)
f.write(b)

payload.close()
f.close()

# 0x0160 - 0x1E8(?)
# Out:
# 0x1c6

# %%
payload = open("../Super Mario Bros. (W) [!].bin","rb")
f = open("./RAM_OLD.dump","wb")

b = payload.read(0x16B)
f.write(b)

b = payload.read(0x16) # ReadController @ 0x016B
f.write(b)

# DISPLAY INPUT * 0x8F
asm = b"" # :Entry @ 0x0181
# LDA # $10 ; READ 0x10
asm += (b"\xA9"+b"\x03")
# STA zpg $C1
asm += (b"\x85"+b"\xC1")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA zpg $C2
asm += (b"\x85"+b"\xC2")
# LDA # $03
asm += (b"\xA9"+b"\x03")
# STA zpg $C3
asm += (b"\x85"+b"\xC3")
# LDY # $00
asm += (b"\xA0"+b"\x00") 
asm += b"" # :Loop @ 0x018f
# JSR $016B
asm += (b"\x20"+b"\x6B"+b"\x01")
# STA (ind), Y $C2
asm += (b"\x91"+b"\xC2")
asm += b"" # :Wait @ 0x0194
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL @ 0x194 -> Wait -0x05
asm += (b"\x10"+b"\xFB")
# INY
asm += (b"\xC8")
# CPY zpg $C1
asm += (b"\xC4"+b"\xC1")
# BCC @ 0x019C -> Loop -0x0F
asm += (b"\x90"+b"\xF1")

# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $21
asm += (b"\xA9"+b"\x21")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $CA
asm += (b"\xA9"+b"\xCA")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# JSR $016B
asm += (b"\x20"+b"\x6B"+b"\x01")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# LDA # $20
asm += (b"\xA9"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# STA abs $2005
asm += (b"\x8D"+b"\x05"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL @ 0x194 -> Wait -0x05
asm += (b"\x10"+b"\xFB")
# LDA # $0E
asm += (b"\xA9"+b"\x0E")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $10
asm += (b"\xA9"+b"\x10")
# STA abs $2000
asm += (b"\x8D"+b"\x00"+b"\x20")
asm += b"" # :Lock @ 0x1C3
# JMP @0x01DB -> Lock
asm += (b"\x4C"+b"\xDB"+b"\x01")

l = len(asm)
print(hex(0x16B+0x16+l))
if l > 0x1E0-0x181:
    print("Error!")

payload.read(l)
b = payload.read(0x67F-l)
f.write(asm)
f.write(b)

payload.close()
f.close()

# 0x0160 - 0x1E8(?)
# Out:
# 0x1de

# %%
payload = open("../Super Mario Bros. (W) [!].bin","rb")
f = open("./RAM.dump","wb")

b = payload.read(0x16B)
f.write(b)

b = payload.read(0x16) # ReadController @ 0x016B
f.write(b)

# DISPLAY INPUT * 0x8F
asm = b"" # :Entry @ 0x0181

# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $21
asm += (b"\xA9"+b"\x21")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $A3
asm += (b"\xA9"+b"\xA3")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")

# LDX # ::$!
asm += (b"\xA2"+b"\x1C") 
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL -0x05
asm += (b"\x10"+b"\xFB")
# DEX
asm += (b"\xCA")
# BPL -0x08
asm += (b"\x10"+b"\xF8")

# LDY # $00
asm += (b"\xA0"+b"\x00")
# LDX # $9A
asm += (b"\xA2"+b"\x9A")
# STX abs $2007
asm += (b"\x8E"+b"\x07"+b"\x20")
# JSR $016B
asm += (b"\x20"+b"\x6B"+b"\x01")
# STA abs $2007
asm += (b"\x8D"+b"\x07"+b"\x20")
# STX abs $2007
asm += (b"\x8E"+b"\x07"+b"\x20")
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL -0x05
asm += (b"\x10"+b"\xFB")
# INY
asm += (b"\xC8")
# CPY # $08
asm += (b"\xC0"+b"\x08")
# BCC -0x13
asm += (b"\x90"+b"\xED")

# LDA # $20
asm += (b"\xA9"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA # $00
asm += (b"\xA9"+b"\x00")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# STA abs $2005
asm += (b"\x8D"+b"\x05"+b"\x20")
# STA abs $2006
asm += (b"\x8D"+b"\x06"+b"\x20")
# LDA abs $2002
asm += (b"\xAD"+b"\x02"+b"\x20")
# BPL -0x05
asm += (b"\x10"+b"\xFB")
# LDA # $0E
asm += (b"\xA9"+b"\x0E")
# STA abs $2001
asm += (b"\x8D"+b"\x01"+b"\x20")
# LDA # $10
asm += (b"\xA9"+b"\x10")
# STA abs $2000
asm += (b"\x8D"+b"\x00"+b"\x20")
asm += b"" # :Lock @ 0x01D3
# JMP @0x01D3 -> Lock
asm += (b"\x4C"+b"\xD3"+b"\x01")

l = len(asm)
print(hex(0x16B+0x16+l))
if l > 0x1E0-0x181:
    print("Error!")

payload.read(l)
b = payload.read(0x67F-l)
f.write(asm)
f.write(b)

payload.close()
f.close()

# 0x0160 - 0x1E8(?)
# Out:
# 0x1d6

# %%
bin(0x25)
0b00100101
# Out:
# '0b100101'

# %%
f = open("./flag2-hasagi.fm2","r")
o = open("./TAS.fm2","w")
for i in range(12):
    s = f.readline()
    o.writelines(s)
t0 = f.readline()
f.close()

o.writelines(t0)

f = open("./INPUT.txt","r")

f.readline()
f.readline()

for i in range(59):
    s = f.readline()

for i in range(32):
    t = list(t0)
    t[1] = "0"
    o.writelines("".join(t))

t = list(t0)
t[1] = "0"
t[7] = "T"
t[10] = "A"
o.writelines("".join(t))

for i in range(322):
    s = f.readline()

for i in range(161):
    t = list(t0)
    t[1] = "0"
    o.writelines("".join(t))

for i in range(1591):
    t = list(t0)
    t[1] = "0"
    s1 = f.readline()
    s1 = s1[6:]
    s2 = f.readline()
    s2 = s2[6:]
    if s1[4] != "." or s2[4] != ".":
        t[6] = "U"
    if s1[5] != "." or s2[5] != ".":
        t[5] = "D"
    if s1[6] != "." or s2[6] != ".":
        t[4] = "L"
    if s1[7] != "." or s2[7] != ".":
        t[3] = "R"
    if s1[8] != "." or s2[8] != ".":
        t[7] = "T"
    if s1[9] != "." or s2[9] != ".":
        t[8] = "S"
    if s1[10] != "." or s2[10] != ".":
        t[9] = "B"
    if s1[11] != "." or s2[11] != ".":
        t[10] = "A"
    o.writelines("".join(t))

for i in range(696):
    t = list(t0)
    t[1] = "0"
    o.writelines("".join(t))

for i in range(1391):
    f.readline()

for i in range(1908):
    t = list(t0)
    t[1] = "0"
    s1 = f.readline()
    s1 = s1[6:]
    s2 = f.readline()
    s2 = s2[6:]
    if s1[4] != "." or s2[4] != ".":
        t[6] = "U"
    if s1[5] != "." or s2[5] != ".":
        t[5] = "D"
    if s1[6] != "." or s2[6] != ".":
        t[4] = "L"
    if s1[7] != "." or s2[7] != ".":
        t[3] = "R"
    if s1[8] != "." or s2[8] != ".":
        t[7] = "T"
    if s1[9] != "." or s2[9] != ".":
        t[8] = "S"
    if s1[10] != "." or s2[10] != ".":
        t[9] = "B"
    if s1[11] != "." or s2[11] != ".":
        t[10] = "A"
    o.writelines("".join(t))
    
o.writelines("|0|........|........||\n")
o.writelines("|0|........|........||\n")
o.writelines("|0|R.......|........||\n")
o.writelines("|0|RL......|........||\n")
o.writelines("|0|RLD.....|........||\n")
o.writelines("|0|RLDU....|........||\n")
o.writelines("|0|RLDUT...|........||\n")
o.writelines("|0|RLDUTS..|........||\n")
o.writelines("|0|RLDUTSB.|........||\n")
o.writelines("|0|RLDUTSBA|........||\n")
o.writelines("|0|RLDUTS..|........||\n")
o.writelines("|0|RLDUT...|........||\n")
o.writelines("|0|RLDU....|........||\n")
o.writelines("|0|RLD.....|........||\n")
o.writelines("|0|RL......|........||\n")
o.writelines("|0|R.......|........||\n")
o.writelines("|0|........|........||\n")
for i in range(256):
    o.writelines("|0|RLDUTSBA|........||\n")

# # for i in range(10000):
# #     s = f.readline()
# #     if s != "|    0,..|........|\n":
# #         print(i)
# #         break

o.close()

# %%
f = open("./TAS.fm2","r")
o = open("./FLAG3","wb")
for i in range(14):
    s = f.readline()
while len(s) == 23:
    b = 0
    for i in range(8):
        if s[10-i]!='.':
            b |= 1<<i
            # print(s[10-i],end='')
    o.write(int.to_bytes(b,1,'big'))
    s = f.readline()
f.close()
o.close()
