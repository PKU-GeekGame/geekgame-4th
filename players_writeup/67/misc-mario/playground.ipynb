# %%
# https://tasvideos.org/1715M
f = open("./happylee-supermariobros,warped.fm2","r")
o = open("./flag1","wb")
for i in range(14):
    s = f.readline()
while len(s) == 23:
    b = 0
    for i in range(8):
        if s[10-i]!='.':
            b |= 1<<i
            # print(s[10-i],end='')
    o.write(int.to_bytes(b,1,'big'))
    s = f.readline()
for i in range(600):
    b = 0
    o.write(int.to_bytes(b,1,'big'))
f.close()
o.close()

# %%
# https://tasvideos.org/1715M
f = open("./happylee-supermariobros,warped.fm2","r")
# o = open("./flag2","wb")
o = open("./flag2-hasagi.fm2","w")
for i in range(14):
    s = f.readline()
    o.writelines(s)
for i in range(3616):
    s = f.readline()
    o.writelines(s)
# o.writelines("|0|R.....BA|........||\n") # 3743
# for i in range(20):
#     o.writelines("|0|R.....B.|........||\n")
for i in range(113):
    o.writelines("|0|........|........||\n")
o.writelines("|0|R......A|........||\n")
for i in range(14):
    o.writelines("|0|R.......|........||\n")
for i in range(22):
    o.writelines("|0|........|........||\n")
o.writelines("|0|..D.....|........||\n")
for i in range(51):
    o.writelines("|0|........|........||\n")
f.close()
o.close()

# %%
f = open("./flag2-hasagi.fm2","r")
o = open("./flag2","wb")
for i in range(14):
    s = f.readline()
while len(s) == 23:
    b = 0
    for i in range(8):
        if s[10-i]!='.':
            b |= 1<<i
            # print(s[10-i],end='')
    o.write(int.to_bytes(b,1,'big'))
    s = f.readline()
for i in range(600):
    b = 0
    o.write(int.to_bytes(b,1,'big'))
f.close()
o.close()

# %% [markdown]
# 0x66 0b01100110 -> 0x66 f
# 0x36 0b00110110 -> 0x6C l
# 0x86 0b10000110 -> 0x61 a
# 0xE6 0b11100110 -> 0x67 g
#
# 0xDE 0b11011110 -> 0x7B {
# 0xC6 0b11000110 -> 0x63 c
# 0xF6 0b11110110 -> 0x6F o
# 0xF2 0b11110010 -> 0x4F O
#
# 0x36 0b00110110 -> 0x6C l
# 0xB4 0b10110100 -> 0x2D -
# 0x82 0b10000010 -> 0x41 A
# 0x4A 0b01001010 -> 0x52 R
#
# 0x42 0b01000010 -> 0x42 B
# 0x96 0b10010110 -> 0x69 i
# 0x2E 0b00101110 -> 0x74 t
# 0x4A 0b01001010 -> 0x52 R
#
# 0x86 0b10000110 -> 0x61 a
# 0x4E 0b01001110 -> 0x72 r
# 0x9A 0b10011010 -> 0x59 Y
# 0xFA 0b11111010 -> 0x5F _
#
# 0xC6 0b11000110 -> 0x63 c
# 0xF2 0b11110010 -> 0x4F O
# 0x22 0b00100010 -> 0x44 D
# 0xA2 0b10100010 -> 0x45 E
#
# 0xB4 0b10110100 -> 0x2D -
# 0xA2 0b10100010 -> 0x45 E
# 0x1A 0b00011010 -> 0x58 X
# 0xA2 0b10100010 -> 0x45 E
#
# 0xC6 0b11000110 -> 0x63 c
# 0xBE 0b10111110 -> 0x7D }
# 0x50 0b01010000 -> 0x0A # LineFeed
#
# flag{coOl-ARBitRarY_cODE-EXEc}
